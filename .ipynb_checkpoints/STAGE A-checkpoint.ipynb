# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.describe()
#to find mean and standard deviation for year 2015
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df['Area'].nunique()
#to find the number of unique countries in the dataset
# Out:
# 49

# %%
Y2016 =[df['Y2016']]

# %%
print(df['Y2016'].isnull().sum())
#to find number of missing items in 2016
# Out:
# 1535

# %%
print(df['Element Code'].corr(df['Y2014']))
print(df['Element Code'].corr(df['Y2015']))
print(df['Element Code'].corr(df['Y2016']))
print(df['Element Code'].corr(df['Y2017']))
print(df['Element Code'].corr(df['Y2018']))
#to compare correlation between element code and the different years.
# Out:
# 0.024456819495221754
# 0.02388919930163996
# 0.023443997584961424
# 0.02425400776004575
# 0.024278571953519557

# %%
Y2017 =[df['Y2017']]

# %%
Y2015 =[df['Y2015']]

# %%
Y2014 =[df['Y2014']]

# %%
Y2018 =[df['Y2018']]

# %%
Years= df.groupby('Element')['Y2018', 'Y2017','Y2016', 'Y2015', 'Y2014'].sum()
#to find the year with the highest import quantity
#to find total sum of production in 2014
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18816\630872012.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Years= df.groupby('Element')['Y2018', 'Y2017','Y2016', 'Y2015', 'Y2014'].sum()

# %%
Years
# Out:
#                                              Y2018       Y2017       Y2016  \
# Element
# Domestic supply quantity                2161192.10  2088198.10  2044842.70
# Export Quantity                          181594.80   182338.80   151920.46
# Fat supply quantity (g/capita/day)        10258.69    10253.84    10102.77
# Feed                                     233489.68   223705.68   228958.65
# Food                                    1303841.28  1258888.28  1247022.17
# Food supply (kcal/capita/day)            455261.00   454681.00   451810.00
# Food supply quantity (kg/capita/yr)       49056.85    48690.04    48985.28
# Import Quantity                          287997.09   294559.09   286582.78
# Losses                                   163902.00   160614.00   157787.00
# Other uses (non-food)                     91300.97    91645.97    69563.68
# Processing                               308429.00   292836.00   280631.00
# ...

# %%
Y2018_Element = df.groupby('Element')['Y2018'].sum()
#to find the elements with the highest sum in 2018

# %%
Y2018_Element.max()
#to find the the highest element in 2018
# Out:
# 2161192.1

# %%
Y2018_Element.sort_values()
#to find the third lowest element in 2018
# Out:
# Element
# Tourist consumption                            90.00
# Fat supply quantity (g/capita/day)          10258.69
# Protein supply quantity (g/capita/day)      11833.56
# Stock Variation                             20577.91
# Seed                                        25263.14
# Residuals                                   34864.00
# Food supply quantity (kg/capita/yr)         49056.85
# Other uses (non-food)                       91300.97
# Losses                                     163902.00
# Export Quantity                            181594.80
# Feed                                       233489.68
# Import Quantity                            287997.09
# Processing                                 308429.00
# Food supply (kcal/capita/day)              455261.00
# Total Population - Both sexes             1140605.00
# Food                                      1303841.28
# Production                                2075072.89
# Domestic supply quantity                  2161192.10
# ...

# %%
Y2014_Element = df.groupby('Element')['Y2014'].sum()
#to find total sum of production in 2014

# %%
Y2014_Element
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...
